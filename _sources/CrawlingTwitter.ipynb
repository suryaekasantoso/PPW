# %% [markdown]
# # Crawling Twitter

# %% [markdown]
# ## Crawling data use tweet-harvest

# %%
# Install dependencies system untuk Playwright
# !apt-get update
# !apt-get install -y \
    libatk1.0-0 \
    libatk-bridge2.0-0 \
    libcups2 \
    libxkbcommon0 \
    libxcomposite1 \
    libxdamage1 \
    libxrandr2 \
    libgbm1 \
    libpango-1.0-0 \
    libcairo2 \
    libasound2 \
    libnss3 \
    libnspr4

# Install Playwright browser
# !playwright install chromium
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://cli.github.com/packages stable InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# Sekarang jalankan tweet-harvest
filename = "datatweet.csv"
search_keyword = 'makan bergizi gratis since:2024-01-01 until:2025-09-09 lang:id'
limit = 2000

# Ganti dengan token Anda yang valid
twitter_auth_token = "ccc9135cb70a2204c62900ef8857589a03878353"

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: makan bergizi gratis since:2024-01-01 until:2025-09-09 lang:id
#
#  (4)
#
# Your tweets saved to: /content/tweets-data/datatweet.csv
# Total tweets saved: 20
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/datatweet.csv
# Total tweets saved: 38
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/datatweet.csv
# Total tweets saved: 58
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/datatweet.csv
# Total tweets saved: 73
#
# -- Scrolling... (1) (2) (3)
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1965198128296112318  Mon Sep 08 23:38:40 +0000 2025               0
# 1     1965197767946764488  Mon Sep 08 23:37:14 +0000 2025               4
# 2     1964954691181441423  Mon Sep 08 23:20:25 +0000 2025               0
# 3     1965027528030167440  Mon Sep 08 23:19:17 +0000 2025               0
# 4     1965186883237150930  Mon Sep 08 22:53:59 +0000 2025               0
# ...                   ...                             ...             ...
# 1311  1961355187194609731  Fri Aug 29 09:08:19 +0000 2025               0
# 1312  1961355187194609731  Fri Aug 29 09:08:15 +0000 2025               0
# 1313  1961355187194609731  Fri Aug 29 09:08:11 +0000 2025               0
# 1314  1961288319322456358  Fri Aug 29 08:59:02 +0000 2025               0
# 1315  1961348731682349085  Fri Aug 29 08:42:32 +0000 2025               0
#
#                                               full_text               id_str  \
# ...

# %% [markdown]
# - cek duplikasi
